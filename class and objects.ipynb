# %%
class sri:
    def __init__(self,name,age):
        self.name=name
        self.age=age
s=sri('srinivas',20)
print(s.name,s.age)
# Out:
# srinivas 20

# %%
class sri:
    def __init__(self,name,age):
        self.name=name
        self.age=age
s1=input("enter name")
s2=int(input("enter age"))
print(s1,s2)
# Out:
# enter namesrinivas
# enter age20
# srinivas 20

# %%
class sri:
    def __init__(self):
        self.name=input("enter name")
        self.age=int(input("enter age"))
s=sri()
print(s.name,s.age)
# Out:
# enter namesrinivas
# enter age20
# srinivas 20

# %%
a=20
type(a)
# Out:
# int

# %% [markdown]
# # inheritance and abstraction

# %%
class A:
    def fun1(self):
        print("hii")
    #def _fun3_(self):        # making fun3 protected (abstraction)
        #print("how are you")
class B(A):
    def fun2(self):
        print("hello")
o=B()
o.fun1()
o.fun2()
#o.fun3()
# Out:
# hii
# hello

# %%
class A:
    def __init__(self,a,b):
        self.a=a
        self._b=b
    def printB(self):
        print(slef._b)
o=A(10,20)
print(o.a,o._b)
#print(o._b)
# Out:
# 10 20
# 20

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
class Student:
    def __init__(self):
        self.name=input("enter name")
        self.usn=input("enter usn")
        for i in range(5):
            self.sub=input("enter sub name")
            self.marks=int(input("enter marks"))
            self.per=input("enter percetage")
            self.grade=input("enter grade")
    def details(self):
        print(self.name,self.usn)
        for i in range(5):
            print(self.sub,self.marks,self.per,self.grade)
     
        
            
o=Student()
o.details()
# Out:
# enter namesd
# enter usn123
# enter sub namesd
# enter marks123
# enter percetagesd
# enter gradesd
# enter sub nameasd
# enter marks23
# enter percetageasd
# enter gradesd
# enter sub namesd
# enter marks23
# enter percetageasd
# enter gradesd
# enter sub namesd
# enter marks2
# enter percetageas
# enter gradeasd
# enter sub nameasd
# enter marks123
# enter percetageasd
# enter gradeasd
# sd 123
# asd 123 asd asd
# asd 123 asd asd
# asd 123 asd asd
# asd 123 asd asd
# asd 123 asd asd

# %%
class Student:
    def _init_(self):
        self.name = input("Enter name: ")
        self.usn = input("Enter USN: ")
        self.subjects = []
        self.marks = []
        self.percentages = []
        self.grades = []

        for i in range(5):
            sub = input("Enter subject name: ")
            mark = int(input("Enter marks: "))
            per = input("Enter percentage: ")
            grade = input("Enter grade: ")
            
            self.subjects.append(sub)
            self.marks.append(mark)
            self.percentages.append(per)
            self.grades.append(grade)
    
    def details(self):
        print(f"Name: {self.name}, USN: {self.usn}")
        for i in range(5):
            print(f"Subject: {self.subjects[i]}, Marks: {self.marks[i]}, Percentage: {self.percentages[i]}, Grade: {self.grades[i]}")

o = Student()
o.details()
# Out:
# Enter name: sri
# Enter USN: 108
# Enter subject name: s1
# Enter marks: 12
# Enter subject name: s2
# Enter marks: 23
# Enter subject name: s3
# Enter marks: 34
# Enter subject name: s4
# Enter marks: 45
# Enter subject name: s5
# Enter marks: 56
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 23
#      20         for i in range(5):
#      21             print(f"Subject: {self.subjects[i]}, Marks: {self.marks[i]}")
# ---> 23 o = Student()
#      24 o.details()
#
# Cell In[54], line 16, in Student.__init__(self)
#      14     self.marks.append(mark)
#      15 for i in range(len(self.marks)):
# ---> 16     self.percentages =sum(self.marks[i])/len(marks)
#
# TypeError: 'int' object is not iterable

# %%
class Student:
    def __init__(self,):
        self.name = input("Enter name: ")
        self.usn = input("Enter USN: ")
        self.subjects = []
        self.marks = []
        self.percentage=None
        
        for i in range(2):
            sub = input("Enter subject name: ")
            mark = int(input("Enter marks: "))
            self.subjects.append(sub)
            self.marks.append(mark)
        sum=0
        for i in self.marks:
            sum=sum+i
        self.percentage=(sum/len(self.marks)*100)*100
    def details(self):
        print(f"Name: {self.name}, USN: {self.usn}")
        for i in range(2):
            print(f"Subject: {self.subjects[i]}, Marks: {self.marks[i]}")
            print("per",self.percentage)

o = Student()
o.details()
# Out:
# Enter name: sri
# Enter USN: 108
# Enter subject name: s1
# Enter marks: 78
# Enter subject name: s2
# Enter marks: 78
# Name: sri, USN: 108
# Subject: s1, Marks: 78
# per 780000.0
# Subject: s2, Marks: 78
# per 780000.0

# %%
class Student:
    def __init__(self):
        self.name = input("Enter name: ")
        self.usn = input("Enter USN: ")
        self.subjects = []
        self.marks = []
        self.percentage = None
        self.grade=None
        
        for i in range(2):
            sub = input("Enter subject name: ")
            mark = int(input("Enter marks: "))
            self.subjects.append(sub)
            self.marks.append(mark)
        
        smarks = sum(self.marks)
        self.percentage = (smarks / (len(self.marks) * 100)) * 100
        
        if self.percentage>=100 and self.percentage<90:
            self.grade='A'
        elif self.percentage>=89 and self.percentage<79:
            self.grade="B"
        elif self.percentage>=65 and self.percentage<50:
            self.grade="c"
        #else:
         #   self.grade="pass"

    def details(self):
        print(f"Name: {self.name}, USN: {self.usn}")
        for i in range(2):
            print(f"Subject: {self.subjects[i]}, Marks: {self.marks[i]}")
        print(f"Percentage: {self.percentage:.2f}%")
        print(f"grade : {self.grade}")
        

o = Student()
o.details()
# Out:
# Enter name: sri
# Enter USN: 108
# Enter subject name: s1
# Enter marks: 98
# Enter subject name: s2
# Enter marks: 98
# Name: sri, USN: 108
# Subject: s1, Marks: 98
# Subject: s2, Marks: 98
# Percentage: 98.00%
# grade : None

# %%
class Student:
    def __init__(self):
        self.name = input("Enter name: ")
        self.usn = input("Enter USN: ")
        self.subjects = []
        self.marks = []
        self.percentage = None
        self.grade = None
        
        for i in range(2):
            #sub = input("Enter subject name: ")
            mark = int(input(f"Enter sub {i+1} marks"))
            #self.subjects.append(sub)
            self.marks.append(mark)
        
        smarks = sum(self.marks)
        self.percentage = (smarks / (len(self.marks) * 100)) * 100
        
        if 80 <= self.percentage <= 100:
            self.grade = 'A'
        elif 65 <= self.percentage < 80:
            self.grade = 'B'
        elif 50 <= self.percentage < 65:
            self.grade = 'C'
        else:
            self.grade = 'Fail'

    def details(self):
        print(f"Name: {self.name}, USN: {self.usn}")
        for i in range(2):
            print(f"Subject: {i+1}, Marks: {self.marks[i]}")
        print(f"Percentage: {self.percentage:.2f}%")
        print(f"Grade: {self.grade}")
    
    def c_lis(self):
        lis=[self.name,self.usn,self.marks,self.percentage,self.grade]
        return lis
    def c_ob(self,lis):
        self.name=lis[0]
        self.usn=lis[1]
        self.marks=lis[2].copy()
        self.percentage=lis[3]
        self.grade=lis[4]
# Out:
#   Cell In[23], line 41
#     self.marks=*lis[2].copy()
#                ^
# SyntaxError: can't use starred expression here

# %%
s=[]
with open("xyz1.txt",'rb') as f:
    data=f.readline().decode('utf-8')
    print(data)
    for i in data.split(','):
        s.append(i)
print(s)
# Out:
# fgf,45,[667, 787],727.0,Fail
# ['fgf', '45', '[667', ' 787]', '727.0', 'Fail']

# %%
stobj = []
num_students = int(input("Enter the number of students: "))
for i in range(num_students):
    s = Student()  
    stobj.append(s)  
for i in range(num_students):
    stobj[i].details() 
    stobj[i].c_lis()
# Out:
# Enter the number of students: 2
# Enter name: de
# Enter USN: 45
# Enter marks for subject 1: 565
# Enter marks for subject 2: 67
# Enter name: fgf
# Enter USN: 45
# Enter marks for subject 1: 667
# Enter marks for subject 2: 787
# Name: de, USN: 45
# Subject 1, Marks: 565
# Subject 2, Marks: 67
# Percentage: 316.00%
# Grade: Fail
# Name: fgf, USN: 45
# Subject 1, Marks: 667
# Subject 2, Marks: 787
# Percentage: 727.00%
# Grade: Fail

# %%
with open('xyz1.txt', 'w') as file:
    pass

# %%
with open("xyz1.txt",'ab') as f:
    l=s.c_lis()
    data=f"{l[0]},{l[1]},{l[2]},{l[3]},{l[4]}"
    f.write(data.encode())
    f.close()

# %%
with open("xyz1.txt", 'ab') as f:
    for s in stobj:
        l = s.c_lis()
      
        marks_str = ','.join(map(str, l[2]))
    
        data = f"{l[0]},{l[1]},{marks_str},{l[3]},{l[4]}\n"
       
        f.write(data.encode())

# %%
class Student:
    def __init__(self):
        self.name = input("Enter name: ")
        self.usn = input("Enter USN: ")
        self.subjects = []
        self.marks = []
        self.percentage = None
        self.grade = None
        
        for i in range(2):
            #sub = input("Enter subject name: ")
            mark = int(input(f"Enter sub {i+1} marks"))
            #self.subjects.append(sub)
            self.marks.append(mark)
        
        smarks = sum(self.marks)
        self.percentage = (smarks / (len(self.marks) * 100)) * 100
        
        if 80 <= self.percentage <= 100:
            self.grade = 'A'
        elif 65 <= self.percentage < 80:
            self.grade = 'B'
        elif 50 <= self.percentage < 65:
            self.grade = 'C'
        else:
            self.grade = 'Fail'

    def details(self):
        print(f"Name: {self.name}, USN: {self.usn}")
        for i in range(2):
            print(f"Subject: {i+1}, Marks: {self.marks[i]}")
        print(f"Percentage: {self.percentage:.2f}%")
        print(f"Grade: {self.grade}")
    
    def c_lis(self):
        lis=[self.name,self.usn,self.marks,self.percentage,self.grade]
        return lis
    def c_ob(self,lis):
        self.name=lis[0]
        self.usn=lis[1]
        self.marks=lis[2].copy()
        self.percentage=lis[3]
        self.grade=lis[4]
stobj = []
num_students = int(input("Enter the number of students: "))
for i in range(num_students):
    s = Student()  
    stobj.append(s)  
for i in range(num_students):
    stobj[i].details() 
    stobj[i].c_lis()
with open("xyz1.txt", 'ab') as f:
    for s in stobj:
        l = s.c_lis()
      
        marks_str = ','.join(map(str, l[2]))
    
        data = f"{l[0]},{l[1]},{marks_str},{l[3]},{l[4]}\n"
       
        f.write(data.encode())
# Out:
# Enter the number of students: 2
# Enter name: sri

# %%
help(range)
# Out:
# Help on class range in module builtins:
#
# class range(object)
#  |  range(stop) -> range object
#  |  range(start, stop[, step]) -> range object
#  |
#  |  Return an object that produces a sequence of integers from start (inclusive)
#  |  to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
#  |  start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
#  |  These are exactly the valid indices for a list of 4 elements.
#  |  When step is given, it specifies the increment (or decrement).
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
# ...
